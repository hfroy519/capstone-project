# %% [markdown]
# # IBM Data Science Capstone Project

# %% [markdown]
# #### Import libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import geojson

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Import geojson files with neighborhood data

# %%
with open('Boundaries - Neighborhoods.geojson') as json_data:
    ChiNeigh = json.load(json_data)
with open('amsterdam.geojson') as json_data:
    AmsNeigh = json.load(json_data)

# %% [markdown]
# #### Create data frame for Chicago neighborhood list

# %%
# define the dataframe columns
column_names = ['Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
df_chi = pd.DataFrame(columns=column_names)

for data in ChiNeigh['features']:
    neighborhood_name = data['properties']['sec_neigh']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[0][0][0][1]
    neighborhood_lon = neighborhood_latlon[0][0][0][0]
    
    df_chi = df_chi.append({'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
df_chi.drop_duplicates(inplace = True)
df_chi.size
# Out:
# 288

# %%
df_chi.head()
# Out:
#          Neighborhood   Latitude  Longitude
# 0         BRONZEVILLE  41.816814 -87.606708
# 1        PRINTERS ROW  41.874371 -87.627607
# 2       UNITED CENTER  41.888852 -87.667069
# 3  SHEFFIELD & DEPAUL  41.921661 -87.658335
# 4       HUMBOLDT PARK  41.887823 -87.740596

# %% [markdown]
# #### Create data frame for Amsterdam neighborhood list

# %%
# define the dataframe columns
column_names = ['Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
df_ams = pd.DataFrame(columns=column_names)

for data in AmsNeigh['features']:
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[0][0][1]
    neighborhood_lon = neighborhood_latlon[0][0][0]
    
    df_ams = df_ams.append({'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
df_ams.drop([69,89], inplace = True)
df_ams
# Out:
#                            Neighborhood Latitude Longitude
# 0                 Burgwallen-Oude Zijde  52.3675   4.89549
# 1               Burgwallen-Nieuwe Zijde  52.3825   4.89877
# 2                   Grachtengordel-West  52.3805    4.8884
# 3                   Grachtengordel-Zuid  52.3674   4.89589
# 4                    Nieuwmarkt/Lastage  52.3799   4.90581
# 5                       Haarlemmerbuurt  52.3888   4.89567
# 6                               Jordaan  52.3819   4.87963
# 7                     De Weteringschans   52.365    4.8845
# 8                 Weesperbuurt/Plantage  52.3692   4.90981
# 9          Oostelijke Eilanden/Kadijken  52.3765   4.91181
# 10                Westelijk Havengebied  52.4311   4.73921
# 11          Bedrijventerrein Sloterdijk  52.3965   4.75787
# 12                           Houthavens   52.393   4.86578
# 13      Spaarndammer- en Zeeheldenbuurt  52.3954   4.85741
# 14                    Staatsliedenbuurt  52.3854   4.88276
# 15                       Centrale Markt  52.3855   4.86947
# 16                Frederik Hendrikbuurt  52.3759   4.87036
# 17                        Da Costabuurt  52.3734   4.87538
# 18                          Kinkerbuurt  52.3718   4.86736
# 19                      Van Lennepbuurt  52.3668   4.87075
# 20                         Helmersbuurt   52.365   4.87927
# 21                     Overtoomse Sluis  52.3616   4.85738
# 22                          Vondelbuurt   52.362   4.88206
# 23                           Sloterdijk  52.3854   4.86465
# 24                             Landlust  52.3851   4.84511
# 25                          Erasmuspark  52.3744   4.85551
# 26                          De Kolenkit   52.385   4.83925
# 27                          De Krommert  52.3754   4.86456
# 28                       Van Galenbuurt  52.3744   4.85551
# 29                 Hoofdweg en omgeving  52.3697   4.84844
# 30                   Westindische buurt  52.3643   4.85813
# 31                         Spieringhorn  52.3848   4.81865
# 32                 Slotermeer-Noordoost  52.3848   4.83162
# 33                  Slotermeer-Zuidwest  52.3848   4.81865
# 34                           Geuzenveld  52.3848   4.81195
# 35                            Eendracht  52.3844   4.79425
# 36                 Lutkemeer en Ookmeer  52.3778   4.75672
# 37                          Osdorp-Oost   52.367   4.80754
# 38                        Osdorp-Midden  52.3627   4.78668
# 39                              De Punt   52.357   4.77666
# 40  Middelveldsche Akerpolder en Sloten  52.3532   4.79182
# 41                          Slotervaart  52.3594   4.81204
# 42                      Overtoomse Veld  52.3721    4.8422
# 43                       Westlandgracht  52.3579   4.83387
# 44              Sloten- en Riekerpolder    52.35   4.80361
# 45                            Oude Pijp  52.3592   4.90466
# 46                          Nieuwe Pijp  52.3534   4.90861
# 47                         Diamantbuurt  52.3534   4.90861
# 48                  Hoofddorppleinbuurt  52.3578   4.85494
# 49                        Schinkelbuurt  52.3563    4.8548
# 50                          Willemspark   52.359   4.86545
# 51                       Museumkwartier  52.3602   4.88737
# 52                         Stadionbuurt  52.3498   4.85736
# 53                          Apollobuurt  52.3507   4.86525
# 54                        Duivelseiland  52.3522    4.8865
# 55                         Scheldebuurt  52.3485   4.88631
# 56                           IJselbuurt    52.35   4.91097
# 57                            Rijnbuurt  52.3464   4.91301
# 58         Station-Zuid WTC en omgeving  52.3444    4.8857
# 59                   Buitenveldert-West  52.3389   4.85742
# 60                   Buitenveldert-Oost  52.3381    4.8847
# 61                         Weesperzijde  52.3592   4.90466
# 62                      Oosterparkbuurt  52.3606    4.9083
# 63                          Dapperbuurt  52.3666   4.93182
# 64                       Transvaalbuurt  52.3553   4.92823
# 65                  Indische Buurt West  52.3666   4.93947
# 66                  Indische Buurt Oost  52.3666   4.93947
# 67                Oostelijk Havengebied  52.3821   4.95241
# 68          Zeeburgereiland/Nieuwe Diep  52.3818   4.95928
# 70                          IJburg Zuid  52.3549   5.00667
# 71                          Frankendael    52.35   4.91644
# 72                           Middenmeer  52.3577   4.93745
# 73                            Betondorp  52.3478   4.94017
# 74                             De Omval  52.3464   4.91301
# 75                          IJburg Oost  52.3669   5.00198
# 76                            Volewijck  52.4009   4.91477
# 77                   Ijplein/Vogelbuurt  52.3867   4.93848
# 78                  Tuindorp Nieuwendam  52.3944   4.94099
# 79                   Tuindorp Buiksloot  52.3952   4.92451
# 80     Nieuwendammerdijk/Buiksloterdijk  52.4009   4.91477
# 81                    Tuindorp Oostzaan  52.4161    4.8748
# 82                        Oostzanerwerf  52.4299   4.86268
# 83                             Kadoelen  52.4245   4.89869
# 84                     Nieuwendam-Noord  52.3944   4.94099
# 85                       Buikslotermeer  52.4117   4.93104
# 86                      Banne Buiksloot  52.4166    4.9205
# 87                        Buiksloterham  52.4149   4.86451
# 88                     Nieuwendammerham  52.3863   4.95238
# 90                 Amstel III/Bullewijk  52.3086   4.92943
# 91            Bijlmer-Centrum (D, F, H)  52.3271   4.94472
# 92               Bijlmer-Oost (E, G, K)  52.3311   4.97789
# 93                           Nellestein  52.3176    4.9969
# 94               Holendrecht/Reigersbos  52.3025   4.95548
# 95                                 Gein  52.3015   5.00783
# 96                             Driemond  52.3245   5.01613

# %% [markdown]
# #### Enter four square credentials

# %%
CLIENT_ID = 'MNDV5G3FTMC10DJORDYHCEHBNQ1FS33HBLUSDJ1AYN4DSMKK' # your Foursquare ID
CLIENT_SECRET = '33NNQJMBQZX4UPM3W33EHXY0JP5G5ANK5IQPR5I1UA3GIU2O' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MNDV5G3FTMC10DJORDYHCEHBNQ1FS33HBLUSDJ1AYN4DSMKK
# CLIENT_SECRET:33NNQJMBQZX4UPM3W33EHXY0JP5G5ANK5IQPR5I1UA3GIU2O

# %% [markdown]
# #### Create function to determine nearby venues by neighborhood latitude and longitude

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, limit=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Run getNearbyVenues on both sets of neighborhood data

# %%
chi_venues = getNearbyVenues(names=df_chi['Neighborhood'],
                                   latitudes=df_chi['Latitude'],
                                   longitudes=df_chi['Longitude']
                                  )
# Out:
# BRONZEVILLE
# PRINTERS ROW
# UNITED CENTER
# SHEFFIELD & DEPAUL
# HUMBOLDT PARK
# GARFIELD PARK
# NORTH LAWNDALE
# LITTLE VILLAGE
# ARMOUR SQUARE,CHINATOWN
# AVALON PARK,CALUMET HEIGHTS
# CHATHAM,BURNSIDE
# BELMONT CRAIGIN,HERMOSA
# IRVING PARK,AVONDALE
# LOGAN SQUARE
# AVALON PARK,CALUMET HEIGHTS
# SOUTHEAST SIDE
# WEST PULLMAN
# MIDWAY AIRPORT
# BACK OF THE YARDS
# ENGLEWOOD
# SOUTH SHORE, GRAND CROSSING
# ASHBURN
# MOUNT GREENWOOD,MORGAN PARK
# MOUNT GREENWOOD,MORGAN PARK
# OHARE
# JACKSON PARK
# LOOP
# PULLMAN
# RIVERDALE
# GREEKTOWN
# BRONZEVILLE
# MUSEUM CAMPUS
# EDGEWATER
# LAKE VIEW
# LINCOLN PARK
# STREETERVILLE
# LINCOLN SQUARE
# OAKLAND,KENWOOD
# GRANT PARK
# WEST LOOP
# BACK OF THE YARDS
# ANDERSONVILLE
# WOODLAWN
# PORTAGE PARK
# RUSH & DIVISION
# LITTLE ITALY, UIC
# KENWOOD,OAKLAND
# ROGERS PARK
# JEFFERSON PARK
# SAUGANASH,FOREST GLEN
# NORTH PARK,ALBANY PARK
# NORTH PARK,ALBANY PARK
# IRVING PARK,AVONDALE
# DUNNING
# WEST RIDGE
# UPTOWN
# NORWOOD PARK
# STREETERVILLE
# SOUTH SHORE, GRAND CROSSING
# CHATHAM,BURNSIDE
# SOUTH CHICAGO
# WASHINGTON HEIGHTS,ROSELAND
# NORTH CENTER
# SOUTHEAST SIDE
# WASHINGTON PARK
# MILLENIUM PARK
# NEAR SOUTH SIDE
# ARMOUR SQUARE,CHINATOWN
# MARQUETTE PARK,GAGE PARK
# AUBURN GRESHAM
# BEVERLY
# WASHINGTON HEIGHTS,ROSELAND
# EDISON PARK
# HYDE PARK
# BUCKTOWN
# LOWER WEST SIDE
# WRIGLEYVILLE
# ARCHER HEIGHTS,WEST ELSDON
# BRIGHTON PARK,MCKINLEY PARK
# BRIGHTON PARK,MCKINLEY PARK
# UKRAINIAN VILLAGE AND EAST VILLAGE
# WICKER PARK,WEST TOWN
# BRIDGEPORT
# ARCHER HEIGHTS,WEST ELSDON
# MARQUETTE PARK,GAGE PARK
# MIDWAY AIRPORT
# WEST LAWN
# WICKER PARK,WEST TOWN
# MONTCLARE, GALEWOOD
# MONTCLARE, GALEWOOD
# OLD TOWN
# BELMONT CRAGIN,HERMOSA
# AUSTIN
# GOLD COAST
# BOYSTOWN
# RIVER NORTH

# %%
ams_venues = getNearbyVenues(names=df_ams['Neighborhood'],
                                   latitudes=df_ams['Latitude'],
                                   longitudes=df_ams['Longitude']
                                  )
# Out:
# Burgwallen-Oude Zijde
# Burgwallen-Nieuwe Zijde
# Grachtengordel-West
# Grachtengordel-Zuid
# Nieuwmarkt/Lastage
# Haarlemmerbuurt
# Jordaan
# De Weteringschans
# Weesperbuurt/Plantage
# Oostelijke Eilanden/Kadijken
# Westelijk Havengebied
# Bedrijventerrein Sloterdijk
# Houthavens
# Spaarndammer- en Zeeheldenbuurt
# Staatsliedenbuurt
# Centrale Markt
# Frederik Hendrikbuurt
# Da Costabuurt
# Kinkerbuurt
# Van Lennepbuurt
# Helmersbuurt
# Overtoomse Sluis
# Vondelbuurt
# Sloterdijk
# Landlust
# Erasmuspark
# De Kolenkit
# De Krommert
# Van Galenbuurt
# Hoofdweg en omgeving
# Westindische buurt
# Spieringhorn
# Slotermeer-Noordoost
# Slotermeer-Zuidwest
# Geuzenveld
# Eendracht
# Lutkemeer en Ookmeer
# Osdorp-Oost
# Osdorp-Midden
# De Punt
# Middelveldsche Akerpolder en Sloten
# Slotervaart
# Overtoomse Veld
# Westlandgracht
# Sloten- en Riekerpolder
# Oude Pijp
# Nieuwe Pijp
# Diamantbuurt
# Hoofddorppleinbuurt
# Schinkelbuurt
# Willemspark
# Museumkwartier
# Stadionbuurt
# Apollobuurt
# Duivelseiland
# Scheldebuurt
# IJselbuurt
# Rijnbuurt
# Station-Zuid WTC en omgeving
# Buitenveldert-West
# Buitenveldert-Oost
# Weesperzijde
# Oosterparkbuurt
# Dapperbuurt
# Transvaalbuurt
# Indische Buurt West
# Indische Buurt Oost
# Oostelijk Havengebied
# Zeeburgereiland/Nieuwe Diep
# IJburg Zuid
# Frankendael
# Middenmeer
# Betondorp
# De Omval
# IJburg Oost
# Volewijck
# Ijplein/Vogelbuurt
# Tuindorp Nieuwendam
# Tuindorp Buiksloot
# Nieuwendammerdijk/Buiksloterdijk
# Tuindorp Oostzaan
# Oostzanerwerf
# Kadoelen
# Nieuwendam-Noord
# Buikslotermeer
# Banne Buiksloot
# Buiksloterham
# Nieuwendammerham
# Amstel III/Bullewijk
# Bijlmer-Centrum (D, F, H)
# Bijlmer-Oost (E, G, K)
# Nellestein
# Holendrecht/Reigersbos
# Gein
# Driemond

# %% [markdown]
# #### Create list of venue categories for each city and limit each to categories with more than 5 observations

# %%
grouped_chi_venues = chi_venues.groupby('Venue Category').count()
grouped_chi_venues = grouped_chi_venues[grouped_chi_venues['Neighborhood']>5]
grouped_chi_venues.shape
# Out:
# (111, 6)

# %%
grouped_ams_venues = ams_venues.groupby('Venue Category').count()
grouped_ams_venues = grouped_ams_venues[grouped_ams_venues['Neighborhood']>5]
grouped_ams_venues.shape
# Out:
# (120, 6)

# %% [markdown]
# #### Merge list of venue categories to get master list of venue categories with more than 5 observations in each city

# %%
venue_list = grouped_chi_venues.merge(grouped_ams_venues, on = 'Venue Category').index
venue_list
# Out:
# Index(['Art Gallery', 'Arts & Crafts Store', 'Asian Restaurant',
#        'Athletics & Sports', 'Bakery', 'Bar', 'Boat or Ferry', 'Bookstore',
#        'Breakfast Spot', 'Brewery', 'Burger Joint', 'Café',
#        'Chinese Restaurant', 'Clothing Store', 'Coffee Shop',
#        'Convenience Store', 'Cosmetics Shop', 'Dance Studio', 'Deli / Bodega',
#        'Dessert Shop', 'Diner', 'Fast Food Restaurant', 'Food Truck',
#        'Furniture / Home Store', 'Garden', 'Gift Shop', 'Greek Restaurant',
#        'Grocery Store', 'Gym', 'Gym / Fitness Center', 'Harbor / Marina',
#        'Hotel', 'Hotel Bar', 'Ice Cream Shop', 'Indian Restaurant',
#        'Italian Restaurant', 'Japanese Restaurant', 'Jazz Club', 'Lounge',
#        'Mediterranean Restaurant', 'Mexican Restaurant', 'Movie Theater',
#        'Museum', 'Music Venue', 'Park', 'Pet Store', 'Pharmacy', 'Pizza Place',
#        'Playground', 'Plaza', 'Pub', 'Restaurant', 'Sandwich Place',
#        'Seafood Restaurant', 'Snack Place', 'Soccer Field', 'Spa',
#        'Steakhouse', 'Supermarket', 'Sushi Restaurant', 'Tapas Restaurant',
#        'Thai Restaurant', 'Theater', 'Train Station', 'Vietnamese Restaurant',
#        'Wine Shop', 'Women's Store', 'Yoga Studio'],
#       dtype='object', name='Venue Category')

# %% [markdown]
# #### Separate each cities venue list into top venues and other venues. Group by neighborhood to get count of each category type. Add column for the sum of all other venues

# %%
chi_top_venues = chi_venues[chi_venues['Venue Category'].isin(venue_list)]
chi_other_venues = chi_venues[~chi_venues['Venue Category'].isin(venue_list)]
ams_top_venues = ams_venues[ams_venues['Venue Category'].isin(venue_list)]
ams_other_venues = ams_venues[~ams_venues['Venue Category'].isin(venue_list)]

# %%
# one hot encoding
chi_onehot = pd.get_dummies(chi_top_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
chi_onehot['Neighborhood'] = chi_top_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [chi_onehot.columns[-1]] + list(chi_onehot.columns[:-1])
chi_onehot = chi_onehot[fixed_columns]

chi_grouped = chi_onehot.groupby('Neighborhood').sum().reset_index()
chi_other = chi_other_venues.groupby('Neighborhood').count()['Venue']

chi_grouped = chi_grouped[chi_grouped.sum(axis = 1)>5]

chi_grouped = chi_grouped.merge(chi_other, on = 'Neighborhood')
chi_grouped.rename(columns={'Venue':'Other'},inplace = True)

chi_grouped.set_index('Neighborhood',inplace = True)
chi_grouped = chi_grouped.div(chi_grouped.sum(axis=1), axis=0)
chi_grouped.drop(['Other'],axis=1,inplace = True)
chi_grouped = chi_grouped[chi_grouped.apply(lambda x: x!=0)]

# %%
# one hot encoding
ams_onehot = pd.get_dummies(ams_top_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
ams_onehot['Neighborhood'] = ams_top_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [ams_onehot.columns[-1]] + list(ams_onehot.columns[:-1])
ams_onehot = ams_onehot[fixed_columns]

ams_grouped = ams_onehot.groupby('Neighborhood').sum().reset_index()
ams_other = ams_other_venues.groupby('Neighborhood').count()['Venue']

ams_grouped = ams_grouped[ams_grouped.sum(axis = 1)>5]

ams_grouped = ams_grouped.merge(ams_other, on = 'Neighborhood')
ams_grouped.rename(columns={'Venue':'Other'},inplace = True)

ams_grouped.set_index('Neighborhood',inplace = True)
ams_grouped = ams_grouped.div(ams_grouped.sum(axis=1), axis=0)
ams_grouped.drop(['Other'],axis=1,inplace = True)
ams_grouped = ams_grouped[ams_grouped.apply(lambda x: x!=0)]

# %% [markdown]
# #### For each neighborhood pair, calculate similarity

# %%
import scipy

similar_df = pd.DataFrame(columns = ams_grouped.index)

for chi_neigh, row in chi_grouped.iterrows():
    similar_df = similar_df.append(pd.Series(name=chi_neigh))
    for ams_neigh, row in ams_grouped.iterrows():
        similar_df.loc[chi_neigh][ams_neigh] = np.sqrt(np.nansum((chi_grouped.loc[chi_neigh].values.reshape(1, -1) - ams_grouped.loc[ams_neigh].values.reshape(1, -1))**2))
# Out:
# C:\Users\hfroy\anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %% [markdown]
# #### Output results of most similar neighborhood in the opposite city for each city

# %%
similar_df = similar_df.astype('float32')
similar_df.idxmax(axis=0)
# Out:
# Neighborhood
# Apollobuurt                                       ARMOUR SQUARE,CHINATOWN
# Betondorp                                         ARMOUR SQUARE,CHINATOWN
# Buitenveldert-Oost                                          STREETERVILLE
# Buitenveldert-West                                ARMOUR SQUARE,CHINATOWN
# Burgwallen-Nieuwe Zijde                                     ANDERSONVILLE
# Burgwallen-Oude Zijde                                     LOWER WEST SIDE
# Centrale Markt                                                  WEST LOOP
# Da Costabuurt                                               STREETERVILLE
# Dapperbuurt                                               LOWER WEST SIDE
# De Kolenkit                                       ARMOUR SQUARE,CHINATOWN
# De Krommert                                               LOWER WEST SIDE
# De Omval                                                  RUSH & DIVISION
# De Weteringschans                                               WEST LOOP
# Diamantbuurt                                              LOWER WEST SIDE
# Duivelseiland                                               ANDERSONVILLE
# Erasmuspark                                               LOWER WEST SIDE
# Frankendael                                               RUSH & DIVISION
# Frederik Hendrikbuurt                                     LOWER WEST SIDE
# Grachtengordel-West                                         STREETERVILLE
# Grachtengordel-Zuid                                       LOWER WEST SIDE
# Haarlemmerbuurt                                   ARMOUR SQUARE,CHINATOWN
# Helmersbuurt                                                    WEST LOOP
# Holendrecht/Reigersbos                            ARMOUR SQUARE,CHINATOWN
# Hoofddorppleinbuurt                                         STREETERVILLE
# Hoofdweg en omgeving                                        STREETERVILLE
# IJburg Zuid                                                  PRINTERS ROW
# IJselbuurt                                                      WEST LOOP
# Indische Buurt Oost                                          PRINTERS ROW
# Indische Buurt West                                          PRINTERS ROW
# Jordaan                                           ARMOUR SQUARE,CHINATOWN
# Kinkerbuurt                                       ARMOUR SQUARE,CHINATOWN
# Landlust                                          ARMOUR SQUARE,CHINATOWN
# Lutkemeer en Ookmeer                   UKRAINIAN VILLAGE AND EAST VILLAGE
# Middelveldsche Akerpolder en Sloten                              WOODLAWN
# Middenmeer                                                       WOODLAWN
# Museumkwartier                                              ANDERSONVILLE
# Nieuwe Pijp                                               LOWER WEST SIDE
# Nieuwendam-Noord                                   NORTH PARK,ALBANY PARK
# Nieuwmarkt/Lastage                                          ANDERSONVILLE
# Oostelijke Eilanden/Kadijken                              LOWER WEST SIDE
# Oosterparkbuurt                                              PRINTERS ROW
# Osdorp-Midden                                               STREETERVILLE
# Oude Pijp                                               LITTLE ITALY, UIC
# Overtoomse Sluis                                  BELMONT CRAIGIN,HERMOSA
# Overtoomse Veld                                              PRINTERS ROW
# Rijnbuurt                                                 RUSH & DIVISION
# Scheldebuurt                                              LOWER WEST SIDE
# Schinkelbuurt                                               ANDERSONVILLE
# Sloten- en Riekerpolder                UKRAINIAN VILLAGE AND EAST VILLAGE
# Sloterdijk                                                  STREETERVILLE
# Slotermeer-Noordoost                                         PRINTERS ROW
# Slotervaart                                               LOWER WEST SIDE
# Staatsliedenbuurt                                 ARMOUR SQUARE,CHINATOWN
# Stadionbuurt                                                   BRIDGEPORT
# Station-Zuid WTC en omgeving                              LOWER WEST SIDE
# Transvaalbuurt                                     NORTH PARK,ALBANY PARK
# Tuindorp Nieuwendam                                NORTH PARK,ALBANY PARK
# Van Galenbuurt                                            LOWER WEST SIDE
# Van Lennepbuurt                                           LOWER WEST SIDE
# Vondelbuurt                                                     WEST LOOP
# Weesperbuurt/Plantage                                           WEST LOOP
# Weesperzijde                                            LITTLE ITALY, UIC
# Westindische buurt                                          STREETERVILLE
# Westlandgracht                                              STREETERVILLE
# Willemspark                                               LOWER WEST SIDE
# dtype: object

# %%
similar_df.idxmax(axis=1)
# Out:
# ANDERSONVILLE                                    Helmersbuurt
# ARMOUR SQUARE,CHINATOWN                  Slotermeer-Noordoost
# AVALON PARK,CALUMET HEIGHTS              Lutkemeer en Ookmeer
# BACK OF THE YARDS                     Burgwallen-Nieuwe Zijde
# BELMONT CRAGIN,HERMOSA                            Vondelbuurt
# BELMONT CRAIGIN,HERMOSA                           Kinkerbuurt
# BEVERLY                                           Vondelbuurt
# BOYSTOWN                                  Grachtengordel-West
# BRIDGEPORT                                    Van Lennepbuurt
# BRIGHTON PARK,MCKINLEY PARK              Lutkemeer en Ookmeer
# BRONZEVILLE                              Slotermeer-Noordoost
# BUCKTOWN                               Holendrecht/Reigersbos
# CHATHAM,BURNSIDE                         Lutkemeer en Ookmeer
# DUNNING                                  Lutkemeer en Ookmeer
# ENGLEWOOD                                         Kinkerbuurt
# GOLD COAST                                        Frankendael
# GRANT PARK                                 Buitenveldert-West
# GREEKTOWN                                 Grachtengordel-West
# HYDE PARK                                          Sloterdijk
# IRVING PARK,AVONDALE                   Holendrecht/Reigersbos
# JACKSON PARK                                       Sloterdijk
# LAKE VIEW                              Holendrecht/Reigersbos
# LINCOLN PARK                                      Frankendael
# LINCOLN SQUARE                          Burgwallen-Oude Zijde
# LITTLE ITALY, UIC                                 Kinkerbuurt
# LOGAN SQUARE                           Holendrecht/Reigersbos
# LOOP                                     Slotermeer-Noordoost
# LOWER WEST SIDE                                   Vondelbuurt
# MIDWAY AIRPORT                         Holendrecht/Reigersbos
# MILLENIUM PARK                            Grachtengordel-West
# MOUNT GREENWOOD,MORGAN PARK              Lutkemeer en Ookmeer
# MUSEUM CAMPUS                         Burgwallen-Nieuwe Zijde
# NEAR SOUTH SIDE                                Museumkwartier
# NORTH CENTER                             Lutkemeer en Ookmeer
# NORTH PARK,ALBANY PARK                            Willemspark
# OHARE                                    Slotermeer-Noordoost
# OLD TOWN                                 Slotermeer-Noordoost
# PRINTERS ROW                             Slotermeer-Noordoost
# RIVER NORTH                              Slotermeer-Noordoost
# ROGERS PARK                             Burgwallen-Oude Zijde
# RUSH & DIVISION                          Slotermeer-Noordoost
# SHEFFIELD & DEPAUL                     Holendrecht/Reigersbos
# SOUTH SHORE, GRAND CROSSING                       Kinkerbuurt
# STREETERVILLE                            Slotermeer-Noordoost
# UKRAINIAN VILLAGE AND EAST VILLAGE       Lutkemeer en Ookmeer
# UNITED CENTER                                 Overtoomse Veld
# UPTOWN                                 Holendrecht/Reigersbos
# WASHINGTON PARK                          Lutkemeer en Ookmeer
# WEST LOOP                                   De Weteringschans
# WEST RIDGE                                    Van Lennepbuurt
# WICKER PARK,WEST TOWN                    Slotermeer-Noordoost
# WOODLAWN                                          Kinkerbuurt
# WRIGLEYVILLE                                    Da Costabuurt
# dtype: object
